# %% [markdown]
# # Project
#
# ## Data Collection
#
# The data is collected from the following sources:
# - Wikidata
#
# ```sql
# SELECT ?station ?stationLabel ?openingDate ?closingDate ?stateLabel ?coordinates
#        (SAMPLE(?image) AS ?uniqueImage)
#        (GROUP_CONCAT(DISTINCT ?cityLabel; SEPARATOR=", ") AS ?cities)
#        (GROUP_CONCAT(DISTINCT ?lineLabel; SEPARATOR=", ") AS ?lines)
#        (GROUP_CONCAT(DISTINCT ?operatorLabel; SEPARATOR=", ") AS ?operators)
#        (GROUP_CONCAT(DISTINCT ?architectLabel; SEPARATOR=", ") AS ?architects)
#        (SAMPLE(?platforms) AS ?platforms)
#        (SAMPLE(?tracks) AS ?tracks)
#        (SAMPLE(?elevation) AS ?elevation)
#        (SAMPLE(?website) AS ?website)
# WHERE {
#   ?station wdt:P31 wd:Q55488 .  # Select railway stations
#   ?station wdt:P18 ?image .  # Only include stations with images
#   ?station wdt:P17 wd:Q142 .  # Only include stations in France
#   ?station wdt:P1619 ?openingDate .
#   ?station wdt:P625 ?coordinates .  # Ensure uniqueness by coordinates
#
#   OPTIONAL { ?station wdt:P576 ?closingDate . }
#   OPTIONAL { ?station wdt:P5817 ?state . }
#   OPTIONAL { ?station wdt:P131 ?city . ?city rdfs:label ?cityLabel FILTER(LANG(?cityLabel) = "en") }
#   OPTIONAL { ?station wdt:P81 ?line . ?line rdfs:label ?lineLabel FILTER(LANG(?lineLabel) = "en") }
#   OPTIONAL { ?station wdt:P137 ?operator . ?operator rdfs:label ?operatorLabel FILTER(LANG(?operatorLabel) = "en") }
#   OPTIONAL { ?station wdt:P84 ?architect . ?architect rdfs:label ?architectLabel FILTER(LANG(?architectLabel) = "en") }
#   OPTIONAL { ?station wdt:P1103 ?platforms . }
#   OPTIONAL { ?station wdt:P5595 ?tracks . }
#   OPTIONAL { ?station wdt:P2044 ?elevation . }
#   OPTIONAL { ?station wdt:P856 ?website . }
#
#   SERVICE wikibase:label { bd:serviceParam wikibase:language "en,en". }
# }
# GROUP BY ?station ?stationLabel ?openingDate ?closingDate ?stateLabel ?coordinates
# LIMIT 100
# ```

# %% [markdown]
# ## Get images

# %%
import urllib.request
import json
import os
import shutil

user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:135.0) Gecko/20100101 Firefox/135.0"

url = "https://query.wikidata.org/sparql?query=SELECT%20%3Fstation%20%3FstationLabel%20%3FopeningDate%20%3FclosingDate%20%3FstateLabel%20%3Fcoordinates%0A%20%20%20%20%20%20%20(SAMPLE(%3Fimage)%20AS%20%3FuniqueImage)%0A%20%20%20%20%20%20%20(GROUP_CONCAT(DISTINCT%20%3FcityLabel%3B%20SEPARATOR%3D%22%2C%20%22)%20AS%20%3Fcities)%0A%20%20%20%20%20%20%20(GROUP_CONCAT(DISTINCT%20%3FlineLabel%3B%20SEPARATOR%3D%22%2C%20%22)%20AS%20%3Flines)%0AWHERE%20%7B%0A%20%20%3Fstation%20wdt%3AP31%20wd%3AQ55488%20.%20%20%23%20Select%20railway%20stations%0A%20%20%3Fstation%20wdt%3AP18%20%3Fimage%20.%20%20%23%20Only%20include%20stations%20with%20images%0A%20%20%3Fstation%20wdt%3AP17%20wd%3AQ142%20.%20%20%23%20Only%20include%20stations%20in%20France%0A%20%20%3Fstation%20wdt%3AP1619%20%3FopeningDate%20.%20%0A%20%20%3Fstation%20wdt%3AP625%20%3Fcoordinates%20.%20%20%23%20Ensure%20uniqueness%20by%20coordinates%0A%0A%20%20OPTIONAL%20%7B%20%3Fstation%20wdt%3AP576%20%3FclosingDate%20.%20%7D%0A%20%20OPTIONAL%20%7B%20%3Fstation%20wdt%3AP5817%20%3Fstate%20.%20%7D%0A%20%20OPTIONAL%20%7B%20%3Fstation%20wdt%3AP131%20%3Fcity%20.%20%3Fcity%20rdfs%3Alabel%20%3FcityLabel%20FILTER(LANG(%3FcityLabel)%20%3D%20%22en%22)%20%7D%0A%20%20OPTIONAL%20%7B%20%3Fstation%20wdt%3AP81%20%3Fline%20.%20%3Fline%20rdfs%3Alabel%20%3FlineLabel%20FILTER(LANG(%3FlineLabel)%20%3D%20%22en%22)%20%7D%0A%0A%20%20SERVICE%20wikibase%3Alabel%20%7B%20bd%3AserviceParam%20wikibase%3Alanguage%20%22en%2Cen%22.%20%7D%0A%7D%0AGROUP%20BY%20%3Fstation%20%3FstationLabel%20%3FopeningDate%20%3FclosingDate%20%3FstateLabel%20%3Fcoordinates%0ALIMIT%20100%0A&format=json"
request = urllib.request.Request(url, data=None, headers={"User-Agent": user_agent})
with urllib.request.urlopen(request) as response:
    responsedata = json.loads(response.read().decode("utf-8"))

images_urls = []
images_data = []

for data in responsedata["results"]["bindings"]:
    # Extract station name and image URL
    station_name = data["stationLabel"]["value"]
    image_url = data["uniqueImage"]["value"]
    
    # Extract image extension
    image_ext = image_url.split(".")[-1]
    image_path = f"./data/images/{station_name}.{image_ext}"

    # Extract fields with proper handling of optional data
    place = data["cities"]["value"] if "cities" in data else None  # Aggregated city names
    opening_date = data["openingDate"]["value"] if "openingDate" in data else None
    closing_date = data["closingDate"]["value"] if "closingDate" in data else None
    lines = data["lines"]["value"].split(",") if "lines" in data else None  # Aggregated railway lines
    state = data["stateLabel"]["value"] if "stateLabel" in data else None
    coordinates = data["coordinates"]["value"] if "coordinates" in data else None

    # Append to lists
    images_urls.append([station_name, image_url])
    
    images_data.append({
        "name": station_name,
        "imageUrl": image_url,
        "imagePath": image_path,
        "place": place,  # Now contains multiple city names if applicable
        "openingDate": opening_date,
        "closingDate": closing_date,
        "lines": lines,
        "state": state,
        "coordinates": coordinates
    })


print("Found " + str(len(images_urls)) + " images.")

# empty the images folder
try:
    shutil.rmtree("./data/images")
except FileNotFoundError:
    pass
os.makedirs("./data/images")

# download the images
for image in images_urls:
    image_ext = image[1].split(".")[-1]
    image_path = "./data/images/" + image[0] + "." + image_ext

    request = urllib.request.Request(image[1], data=None, headers={"User-Agent": user_agent})
    with urllib.request.urlopen(request) as response:
        if response.status != 200:
            print("Failed to download " + image[0] + "." + image_ext + " (HTTP " + str(response.status) + ").")
            continue
        else:
            open(image_path, "wb").write(response.read())
            print("Downloaded " + image[0] + "." + image_ext)

# writing images data to a json file
with open("./data/images.json", "w") as f:
    json.dump(images_data, f)

print("Downloaded " + str(len(images_urls)) + " images.")

# %% [markdown]
# ## Get metadata

# %%
import PIL.Image
import PIL.ExifTags
import json
from pprint import pprint

with open('./data/images.json') as f:
    json_data = json.load(f)
    i = 0
    # get 5 first images
    for item in json_data:
        print(item)
        print("Opening " + item["imagePath"] + "...")
        img = PIL.Image.open(item["imagePath"])
        if img._getexif() is None:
            print("Failed to get exif data for " + item["name"] + ".")
            continue
        exif = {
            PIL.ExifTags.TAGS[k]: v
            for k, v in img._getexif().items()
            if k in PIL.ExifTags.TAGS
        }
        print(item
              ["name"] + " exif data:")
        input("Press Enter to continue...")
        i += 1
        if i == 5:
            break
# Out:
# {'name': 'Thionville railway station', 'imageUrl': 'http://commons.wikimedia.org/wiki/Special:FilePath/TER%20Lorraine%20L1%20Thionville%20%2820%29.JPG', 'imagePath': './data/images/Thionville railway station.JPG', 'place': 'Thionville', 'openingDate': '1854-01-01T00:00:00Z', 'closingDate': None, 'lines': [''], 'state': 'in use', 'coordinates': 'Point(6.170342 49.35427)'}
# Opening ./data/images/Thionville railway station.JPG...
# Thionville railway station exif data:
# {'name': "Gare d'Avignon TGV", 'imageUrl': 'http://commons.wikimedia.org/wiki/Special:FilePath/TGV%20Avignon%20Sud.JPG', 'imagePath': "./data/images/Gare d'Avignon TGV.JPG", 'place': 'Avignon', 'openingDate': '2001-01-01T00:00:00Z', 'closingDate': None, 'lines': ['LGV Méditerranée'], 'state': 'in use', 'coordinates': 'Point(4.785833333 43.921666666)'}
# Opening ./data/images/Gare d'Avignon TGV.JPG...

# %% [markdown]
# ## Labeling and Annotation

# %%
# %pip install opencv-python pillow scikit-learn exifread tensorflow

# %%
import cv2
import numpy as np
import json
from sklearn.cluster import KMeans
from collections import Counter
from PIL import Image
import exifread
import tensorflow as tf
import webcolors
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input, decode_predictions


# Exif data extraction
def extract_exif(image_path):
    with open(image_path, 'rb') as f:
        tags = exifread.process_file(f)
    return {tag: str(tags[tag]) for tag in tags}

# Image color extraction
def get_dominant_colors(image_path, k=5):
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = image.reshape((-1, 3))

    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(image)
    colors = kmeans.cluster_centers_.astype(int)

    counter = Counter(kmeans.labels_)
    sorted_colors = [colors[i] for i in counter.keys()]

    return sorted_colors

def closest_color(rgb):
    """Find the closest color name for an RGB tuple."""
    min_distances = {}
    for name in webcolors.names("css3"):
        r_c, g_c, b_c = webcolors.name_to_rgb(name)
        min_distances[name] = np.linalg.norm(np.array((r_c, g_c, b_c)) - np.array(rgb))
    
    return min(min_distances, key=min_distances.get)

def generate_color_tags(colors):
    return [closest_color(color) for color in colors]


# Object recognition
def detect_objects(image_path):
    model = ResNet50(weights='imagenet')
    img = Image.open(image_path)

    # Ensure the image is in RGB format, if not (like for old pictures), convert it
    if img.mode != 'RGB':
        img = img.convert('RGB')

    img = img.resize((224, 224))

    # Ensure the image is in the correct format
    x = tf.keras.preprocessing.image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)

    preds = model.predict(x)
    predictions = decode_predictions(preds, top=3)[0]

    # Extract only the class names and probabilities
    object_tags = [(class_name, float(probability)) for _, class_name, probability in predictions]

    return object_tags


# ALL
def analyze_image(image_path):
    # check if the image has already been processed
    if check_json(image_path):
        print("Image " + image_path + " has already been processed.")
        return
    exif_data = extract_exif(image_path)
    colors = get_dominant_colors(image_path)
    color_tags = generate_color_tags(colors)
    print("Color tags: ", color_tags)
    object_tags = detect_objects(image_path)

    result = {
        "image_path": image_path,
        "exif_data": exif_data,
        "predominant_colors": color_tags,
        "object_tags": object_tags
    }

    with open(image_path + "_metadata.json", "w") as f:
        json.dump(result, f, indent=4)

    return result

# check json file validity
def check_json(image_path):
    try:
        with open(image_path + "_metadata.json", "r") as f:
            json.load(f)
        return True
    except ValueError:
        return False
    except FileNotFoundError:
        return False

def process():
    with open('./data/images.json') as f:
        json_data = json.load(f)
        i = 1
        for item in json_data:
            print("Processing " + item["imagePath"] + " (" + str(i) + "/" + str(len(json_data)) + ")...")
            analyze_image(item["imagePath"])
            print("Done.")
            i += 1
            print("------------------------------------")


process()
# Out:
# Processing ./data/images/Thionville railway station.JPG (1/100)...
# Image ./data/images/Thionville railway station.JPG has already been processed.
# Done.
# ------------------------------------
# Processing ./data/images/Gare d'Avignon TGV.JPG (2/100)...
# Image ./data/images/Gare d'Avignon TGV.JPG has already been processed.
# Done.
# ------------------------------------
# Processing ./data/images/Saint-Mariens - Saint-Yzan.JPG (3/100)...
# Image ./data/images/Saint-Mariens - Saint-Yzan.JPG has already been processed.
# Done.
# ------------------------------------
# Processing ./data/images/Gare de Tarascon-sur-Ariège.jpg (4/100)...
# Image ./data/images/Gare de Tarascon-sur-Ariège.jpg has already been processed.
# Done.
# ------------------------------------
# Processing ./data/images/Nanterre – Ville.jpg (5/100)...
# Image ./data/images/Nanterre – Ville.jpg has already been processed.
# Done.
# ------------------------------------
# ...

# %% [markdown]
# ## Data Analyses

# %%
import json
from collections import Counter
from PIL import Image
import os
import random

# Function to determine image orientation
def get_image_orientation(image_path):
    img = Image.open(image_path)
    width, height = img.size
    if width > height:
        return "landscape"
    elif height > width:
        return "portrait"
    else:
        return "square"

# Function to categorize image size
def get_image_size_category(image_path):
    img = Image.open(image_path)
    width, height = img.size
    if width <= 200 and height <= 200:
        return "thumbnail"
    elif width <= 800 and height <= 800:
        return "medium"
    else:
        return "large"

# Function to analyze user preferences
def analyze_user_preferences(user_id, selected_images):
    user_profile = {
        "user_id": user_id,
        "favorite_colors": Counter(),
        "favorite_orientation": Counter(),
        "favorite_sizes": Counter(),
        "favorite_tags": Counter()
    }

    for image in selected_images:
        # Load metadata
        with open(image["imagePath"] + "_metadata.json", "r") as f:
            metadata = json.load(f)

        # Extract predominant colors
        colors = metadata.get("predominant_colors", [])
        for color in colors:
            user_profile["favorite_colors"][color] += 1

        # Determine image orientation
        orientation = get_image_orientation(image["imagePath"] )
        user_profile["favorite_orientation"][orientation] += 1

        # Categorize image size
        size_category = get_image_size_category(image["imagePath"] )
        user_profile["favorite_sizes"][size_category] += 1

        # Collect tags
        tags = metadata.get("user_tags", [])
        for tag in tags:
            user_profile["favorite_tags"][tag] += 1

    return user_profile

# Function to process images and build user profiles
def process_images_and_build_profiles(user_data_path):
    with open(user_data_path) as f:
        user_data = json.load(f)

    # create a folder for user profiles if it does not exist
    if not os.path.exists("./data/user_profiles"):
        os.makedirs("./data/user_profiles")

    for user in user_data:
        user_id = user["user_id"]
        selected_images = user["selected_images"]
        user_profile = analyze_user_preferences(user_id, selected_images)
        print(json.dumps(user_profile, indent=4))
        # Save user profile
        with open(f"./data/user_profiles/{user_id}_profile.json", "w") as f:
            json.dump(user_profile, f, indent=4)

# Function to simulate user input for selecting images and adding tags
def simulate_user_input(images_meta):
    users = []
    tags = ["#train", "#station", "#railway", "#transport", "#travel", "#architecture", "#building", "#city", "#urban", "#infrastructure", "#platform", "#waiting", "#people", "#public", "#commute", "#commuting", "#passenger", "#trainline", "#railroad", "#track", "#traintrack", "#trainstation", "#trainplatform", "#trainwaiting", "#trainpeople", "#trainpassenger", "#traincommute", "#traincommuting", "#trainpublic", "#traininfrastructure", "#trainurban", "#traincity", "#trainbuilding", "#trainarchitecture", "#traintravel", "#traintransport", "#trainrailway", "#trainstation"]
    predominant_colors = ["red", "blue", "green", "yellow", "purple", "orange", "brown", "black", "white", "gray"]

    for i in range(3):  # Simulate 3 users
        user_id = f"user{i+1}"
        selected_images = random.sample(images_meta, k=10)  # Each user selects 2 images
        user_tags = {image["name"]: random.sample(tags, k=random.randint(1, 5)) for image in selected_images}

        users.append({
            "user_id": user_id,
            "selected_images": selected_images,
            "user_tags": user_tags
        })

    with open('./data/users.json', 'w') as f:
        json.dump(users, f, indent=4)


images_meta = []
with open('./data/images.json') as f:
    images_meta = json.load(f)

# Simulate user input
simulate_user_input(images_meta)

# Process images and build user profiles
user_data_path = './data/users.json'
process_images_and_build_profiles(user_data_path)
# Out:
# {
#     "user_id": "user1",
#     "favorite_colors": {
#         "lightslategray": 2,
#         "darkolivegreen": 4,
#         "darkslategray": 5,
#         "lightgray": 4,
#         "darkkhaki": 1,
#         "ghostwhite": 1,
#         "silver": 4,
#         "gray": 4,
#         "dimgray": 5,
#         "lightcyan": 1,
#         "olivedrab": 1,
#         "darkgreen": 1,
#         "wheat": 1,
#         "tan": 1,
#         "gainsboro": 2,
#         "rosybrown": 2,
#         "steelblue": 2,
#         "cornflowerblue": 1,
#         "black": 4,
#         "darkslateblue": 1,
#         "darkgray": 2,
#         "cadetblue": 1
#     },
#     "favorite_orientation": {
#         "landscape": 9,
#         "portrait": 1
#     },
#     "favorite_sizes": {
#         "large": 9,
#         "medium": 1
#     },
#     "favorite_tags": {}
# }
# {
#     "user_id": "user2",
#     "favorite_colors": {
#         "gainsboro": 1,
#         "silver": 3,
#         "darkgray": 2,
#         "dimgray": 6,
# ...

# %% [markdown]
# # Visualisation

# %%
import os
import json
import matplotlib.pyplot as plt
from collections import defaultdict
from datetime import datetime

# Paths
DATA_FOLDER = "./data/images"
USERS_FILE = "./data/users.json"
USER_PROFILE_FILE = "./data/user_profiles/user1_profile.json"
IMAGES_FILE = "./data/images.json"

# ------------------------------------------------------
# -------------------- Extract data --------------------
# ------------------------------------------------------

# Extract importante information of each .json of ./data/images
def load_image_data(folder):
    image_data = []
    for file_name in os.listdir(folder):
        if file_name.endswith(".json"):
            file_path = os.path.join(folder, file_name)
            with open(file_path, "r", encoding="utf-8") as f:
                with open(IMAGES_FILE, "r", encoding="utf-8") as f2:
                    data = json.load(f)
                    data2 = json.load(f2)
                    opening_date = next((item['openingDate'] for item in data2 if item['imagePath'] == data.get("image_path")), "")
                    extracted_data = {
                        "image_path": data.get("image_path"),
                        "image_model": data.get("exif_data", {}).get("Image Make"),
                        "image_orientation": data.get("exif_data", {}).get("Image Orientation"),
                        "image_xresolution": data.get("exif_data", {}).get("Image XResolution"),
                        "image_datetime": data.get("exif_data", {}).get("Image DateTime"),
                        "predominant_colors": data.get("predominant_colors", []),
                        "object_tags": data.get("object_tags"),
                        "opening_date": opening_date
                    }
                    image_data.append(extracted_data)
    return image_data

# Extract Users data
def load_user_data(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        users_data = json.load(f)
    return users_data

# Extract favorite colors of the User profil
def load_user_profile(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        profile_data = json.load(f)
    return profile_data.get("favorite_colors", [])

# ------------------------------------------------------
# ---- image size - image orientation - camera Mark ----
# ------------------------------------------------------

def extract_property_counts(image_data, property_key, selected_image_paths):
    property_counts = defaultdict(int)
    selected_property_counts = defaultdict(int)
    
    for img in image_data:
        property_value = img.get(property_key)
        
        if property_key == "image_datetime" and property_value:
            try:
                year = datetime.strptime(property_value, "%Y:%m:%d %H:%M:%S").year
                property_value = year
            except ValueError:
                continue 
        
        if property_key == "opening_date" and property_value:
            try:
                year = datetime.strptime(property_value, "%Y-%m-%dT%H:%M:%SZ").year
                property_value = year
            except ValueError:
                continue 

        if property_value:
            property_counts[property_value] += 1
            if img["image_path"] in selected_image_paths:
                selected_property_counts[property_value] += 1
    
    return property_counts, selected_property_counts

def plot_counts(counts, selected_counts, title, xlabel):
    labels = sorted(counts.keys(), key=str)
    total_values = [counts[l] for l in labels]
    selected_values = [selected_counts.get(l, 0) for l in labels]
    
    x = range(len(labels))
    
    plt.figure(figsize=(10, 6))
    plt.bar(x, total_values, color='blue', alpha=0.7, label='Total')
    plt.bar(x, selected_values, color='red', alpha=0.7, label='Selected')
    
    plt.xlabel(xlabel)
    plt.ylabel("Nomber")
    plt.title(title)
    plt.xticks(ticks=x, labels=labels, rotation=45)
    plt.legend()
    plt.tight_layout()
    plt.show()

# ------------------------------------------------------
# --------------- Color characteristics ----------------
# ------------------------------------------------------

def extract_color_counts(image_data, favorite_colors):
    color_counts = defaultdict(int)
    
    for img in image_data:
        colors = img.get("predominant_colors", [])
        for color in colors:
            color_counts[color] += 1
    
    return color_counts, favorite_colors

def plot_color_counts(color_counts, favorite_color_counts):
    colors = sorted(color_counts.keys())
    total_counts = [color_counts[c] for c in colors]
    favorite_counts = [favorite_color_counts.get(c, 0) for c in colors]
    
    x = range(len(colors))
    
    plt.figure(figsize=(10, 6))
    plt.bar(x, total_counts, color='blue', alpha=0.7, label='Total Colors')
    plt.bar(x, favorite_counts, color='red', alpha=0.7, label='Favorite Colors')
    
    plt.xlabel("Colors")
    plt.ylabel("Number of images")
    plt.title("number of images by colors")
    plt.xticks(ticks=x, labels=colors, rotation=90)
    plt.legend()
    plt.tight_layout()
    plt.show()

# ------------------------------------------------------
# ---------------------- Main --------------------------
# ------------------------------------------------------

# Extract data
data_images = load_image_data(DATA_FOLDER)
user_data = load_user_data(USERS_FILE)
user_favorite_colors = load_user_profile(USER_PROFILE_FILE)

# Save paths of selected images of the user
selected_images = set(img["imagePath"] for img in user_data[0].get("selected_images", []))

# Plot for image size, image orientation, camera Mark
for key, title, xlabel in [
    ("image_datetime", "Number of images per year", "Year"),
    ("opening_date", "Number of images per opening year", "Year"),
    ("image_model", "Number of images per camera Mark", "Mark"),
    ("image_orientation", "Number of images per orientation ", "Orientation"),
    ("image_xresolution", "Number of images per resolution", "Resolution")
]:
    counts, selected_counts = extract_property_counts(data_images, key, selected_images)
    plot_counts(counts, selected_counts, title, xlabel)

# Plot for Color characteristics
color_counts, favorite_color_counts = extract_color_counts(data_images, user_favorite_colors)
plot_color_counts(color_counts, favorite_color_counts)

# %% [markdown]
# ## User profil visualisation

# %%
import json
import matplotlib.pyplot as plt
import random

# Path
file_path = './data/user_profiles/user1_profile.json'

# ------------------------------------------------------
# -------------------- Extract data --------------------
# ------------------------------------------------------

with open(file_path, 'r') as file:
    data = json.load(file)

favorite_colors = data.get('favorite_colors', {})
favorite_orientations = data.get('favorite_orientation', {})
favorite_sizes = data.get('favorite_sizes', {})

# ------------------------------------------------------
# ------------------- Prepare Colors -------------------
# ------------------------------------------------------

# Process data and group by color (less than 1 --> group in 'other')
def prepare_pie_data(favorite_data):
    data_counts = {}
    for item, count in favorite_data.items():
        if count > 1:
            data_counts[item] = count
        else:
            if 'other' in data_counts:
                data_counts['other'] += count
            else:
                data_counts['other'] = count
    return data_counts

# Random colors
def random_color():
    return f'#{random.randint(0, 255):02x}{random.randint(0, 255):02x}{random.randint(0, 255):02x}'

# ------------------------------------------------------
# ---------------------- Plot --------------------------
# ------------------------------------------------------

# Pie
def plot_pie_chart(data_counts, title, use_random_colors=False):
    labels = list(data_counts.keys())
    sizes = list(data_counts.values())

    colors = []
    for label in labels:
        if label == 'other':
            colors.append('#D3D3D3')  # Other
        elif use_random_colors:
            colors.append(random_color())  # Generate random color
        else:
            colors.append(label)  # If color chart, use label color

    plt.figure(figsize=(8, 8))
    plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, colors=colors, wedgeprops={'edgecolor': 'black'})
    plt.title(title)
    plt.show()

# ------------------------------------------------------
# ---------------------- Main --------------------------
# ------------------------------------------------------

# Prepare
color_counts = prepare_pie_data(favorite_colors)
orientation_counts = prepare_pie_data(favorite_orientations)
size_counts = prepare_pie_data(favorite_sizes)

# Generate charts
plot_pie_chart(color_counts, "Favorite colors")
plot_pie_chart(orientation_counts, "Favorite orientations", use_random_colors=True)
plot_pie_chart(size_counts, "Favorite size", use_random_colors=True)

# %% [markdown]
# # Recommendation System

# %% [markdown]
# ### Dataprep

# %%
import json
import os
from sklearn import tree
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Chemins des fichiers
data_folder = "./data/images/"
images_json_path = "./data/images.json"
users_json_path = "./data/users.json"
user_index = 0

# Charger le fichier images.json
with open(images_json_path, "r", encoding="utf-8") as f:
    images_data = json.load(f)

# Charger le fichier users.json et récupérer les images favorites
with open(users_json_path, "r", encoding="utf-8") as f:
    users_data = json.load(f)
    favorite_images = {img["imagePath"] for img in users_data[user_index].get("selected_images", [])}

# Dictionnaire pour retrouver les métadonnées des images par leur chemin
images_dict = {img["imagePath"]: img for img in images_data}

# Tableaux finaux
result = []
favorite_status = []

# Parcourir les fichiers JSON dans le dossier images
for filename in os.listdir(data_folder):
    if filename.endswith(".json"):
        file_path = os.path.join(data_folder, filename)
        
        with open(file_path, "r", encoding="utf-8") as f:
            image_metadata = json.load(f)
        
        # Récupération des valeurs demandées
        predominant_color = image_metadata.get("predominant_colors", [None])[0]
        object_tag = image_metadata.get("object_tags", [[None]])[0][0]
        image_path = image_metadata.get("image_path")
        
        image_info = images_dict.get(image_path, {})
        opening_date = image_info.get("openingDate", "")[:4]  # Extraire l'année
        state = image_info.get("state", "")
        image_orientation = image_metadata.get("exif_data", {}).get("Image Orientation", "")
        image_make = image_metadata.get("exif_data", {}).get("Image Make", "")
        
        result.append([
            predominant_color,
            object_tag,
            opening_date,
            state,
            image_orientation,
            image_make
        ])
        
        # Vérifier si l'image est favorite
        favorite_status.append("Favorite" if image_path in favorite_images else "NotFavorite")

# creating dataframes
dataframe = pd.DataFrame(result, columns=["predominant_colors", "object_tags", "openingDate", "state", "orientation", "make"])
resultframe = pd.DataFrame(favorite_status, columns=["favorite"])

# generating numerical labels
le1 = LabelEncoder()
dataframe["predominant_colors"] = le1.fit_transform(dataframe["predominant_colors"])

le2 = LabelEncoder()
dataframe["object_tags"] = le2.fit_transform(dataframe["object_tags"])

le3 = LabelEncoder()
dataframe["openingDate"] = le3.fit_transform(dataframe["openingDate"])

le4 = LabelEncoder()
dataframe["state"] = le4.fit_transform(dataframe["state"])

le5 = LabelEncoder()
dataframe["orientation"] = le5.fit_transform(dataframe["orientation"])

le6 = LabelEncoder()
dataframe["make"] = le6.fit_transform(dataframe["make"])

le7 = LabelEncoder()
resultframe["favorite"] = le7.fit_transform(resultframe["favorite"])

# %% [markdown]
# ### Split
# Il faut split le dataset en deux partie. La première partie permet d'entrainer la prediction, la deuxième permet de tester avec de nouvelles valeurs la prediction

# %%
from sklearn.model_selection import train_test_split

# Splitting the dataset
X_train, X_test, y_train, y_test = train_test_split(dataframe.values, resultframe, test_size=0.25, random_state=1)

print("Training Samples: ", len(y_train))
print("Testing  Samples: ", len(y_test))

y_train = y_train.values.ravel()
# Out:
# Training Samples:  75
# Testing  Samples:  25

# %% [markdown]
# ### Prediction

# %% [markdown]
# Ici on essaye de comparer plusieurs méthode de prediction: **Logistic regression**, **SVM**, **DecisionTreeClassifier** et **Random Forest**

# %% [markdown]
# #### DecisionTreeClassifier

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, classification_report
from sklearn import tree

param_grid = {
    'max_depth': [None, 10, 20],
    'criterion': ['gini', 'entropy','log_loss'] 
}
dtc = tree.DecisionTreeClassifier(random_state=1)
grid_search_rf = GridSearchCV(estimator=dtc, param_grid=param_grid)
grid_search_rf.fit(X_train, y_train)
best_params_rf = grid_search_rf.best_params_
rf_model = grid_search_rf.best_estimator_

print("Best Parameters for Random Forest:", best_params_rf)

y_test_pred_rf = rf_model.predict(X_test)
test_accuracy_rf = accuracy_score(y_test, y_test_pred_rf)
print(f"Test Accuracy of the best Random Forest model: {test_accuracy_rf}")
# Out:
# Best Parameters for Random Forest: {'criterion': 'gini', 'max_depth': None}
# Test Accuracy of the best Random Forest model: 0.88

# %% [markdown]
# #### RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

param_grid = {
    'n_estimators': [50, 100, 200,250],
    'max_depth': [None, 10, 20],
    'criterion': ['gini', 'entropy','log_loss'] 
}
rfc = RandomForestClassifier(random_state=1)
grid_search_rf = GridSearchCV(estimator=rfc, param_grid=param_grid)
grid_search_rf.fit(X_train, y_train)
best_params_rf = grid_search_rf.best_params_
rf_model = grid_search_rf.best_estimator_

print("Best Parameters for Random Forest:", best_params_rf)

y_test_pred_rf = rf_model.predict(X_test)
test_accuracy_rf = accuracy_score(y_test, y_test_pred_rf)
print(f"Test Accuracy of the best Random Forest model: {test_accuracy_rf}")
# Out:
# Best Parameters for Random Forest: {'criterion': 'gini', 'max_depth': None, 'n_estimators': 100}
# Test Accuracy of the best Random Forest model: 0.92

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
import numpy as np

param_grid = {
    'penalty': ['l1', 'l2'],
    'C': np.logspace(-3, 3, 7),  
}
logistic = LogisticRegression(solver='liblinear')
grid_search = GridSearchCV(estimator=logistic, param_grid=param_grid)
grid_search.fit(X_train, y_train)
best_params = grid_search.best_params_
logistic_model = grid_search.best_estimator_
print("Best Parameters:", best_params)

y_test_pred = logistic_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
print(f"Test Accuracy of the best model: {test_accuracy}")
# Out:
# Best Parameters: {'C': np.float64(0.001), 'penalty': 'l2'}
# Test Accuracy of the best model: 0.92

# %% [markdown]
# #### SVC

# %%
from sklearn.svm import SVC

param_grid = {
    'C': np.logspace(-3, 3, 7)  
}
svc = SVC(kernel='linear')
grid_search = GridSearchCV(estimator=svc, param_grid=param_grid)
grid_search.fit(X_train, y_train)
best_params = grid_search.best_params_
svm_model = grid_search.best_estimator_
print("Best Parameters:", best_params)
y_test_pred = svm_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
print(f"Test Accuracy of the best SVM model: {test_accuracy}")
# Out:
# Best Parameters: {'C': np.float64(0.001)}
# Test Accuracy of the best SVM model: 0.92

# %% [markdown]
# ### Conclusion
#
# DecisionTreeClassifier est le moins bon (0.88) et les 3 autres sont équivalent (0.92).
# RandomForest est le plus long (plus de paramètre)
# Malgré cela, nous utiliseront pour la suite RandomForest afin dêtre concordant avec les TPs.

# %% [markdown]
# ### Tests RandomForest

# %%
rfc = RandomForestClassifier(n_estimators=100, max_depth=None, criterion='gini')
rfc = rfc.fit(dataframe.values, resultframe.values.ravel())

prediction = rfc.predict(
    [
        [
            le1.transform(["cadetblue"])[0],
            le2.transform(["church"])[0],
            le3.transform(["1875"])[0],
            le4.transform(["decommissioned"])[0],
            le5.transform(["Horizontal (normal)"])[0],
            le6.transform(["Panasonic"])[0],
        ]
    ]
)
print(le7.inverse_transform(prediction))
print(rfc.feature_importances_)
# Out:
# ['Favorite']
# [0.21994365 0.26618319 0.24109937 0.10009823 0.02170349 0.15097207]

# %% [markdown]
# ### User preferences

# %%
feature_importances = pd.DataFrame(
    {'Feature': dataframe.columns, 'Importance': rfc.feature_importances_}
)
print(feature_importances.sort_values(by='Importance', ascending=False))
# Out:
#               Feature  Importance
# 1         object_tags    0.266183
# 2         openingDate    0.241099
# 0  predominant_colors    0.219944
# 5                make    0.150972
# 3               state    0.100098
# 4         orientation    0.021703
